# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, RandomizedSearchCV
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.svm import SVC, LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.neural_network import MLPClassifier

from copy import deepcopy


# %matplotlib inline

# %%
train_df = pd.read_csv('data/train.csv', index_col='Id')
train_df.columns
# Out:
# Index([u'Elevation', u'Aspect', u'Slope', u'Horizontal_Distance_To_Hydrology',
#        u'Vertical_Distance_To_Hydrology', u'Horizontal_Distance_To_Roadways',
#        u'Hillshade_9am', u'Hillshade_Noon', u'Hillshade_3pm',
#        u'Horizontal_Distance_To_Fire_Points', u'Wilderness_Area1',
#        u'Wilderness_Area2', u'Wilderness_Area3', u'Wilderness_Area4',
#        u'Soil_Type1', u'Soil_Type2', u'Soil_Type3', u'Soil_Type4',
#        u'Soil_Type5', u'Soil_Type6', u'Soil_Type7', u'Soil_Type8',
#        u'Soil_Type9', u'Soil_Type10', u'Soil_Type11', u'Soil_Type12',
#        u'Soil_Type13', u'Soil_Type14', u'Soil_Type15', u'Soil_Type16',
#        u'Soil_Type17', u'Soil_Type18', u'Soil_Type19', u'Soil_Type20',
#        u'Soil_Type21', u'Soil_Type22', u'Soil_Type23', u'Soil_Type24',
#        u'Soil_Type25', u'Soil_Type26', u'Soil_Type27', u'Soil_Type28',
#        u'Soil_Type29', u'Soil_Type30', u'Soil_Type31', u'Soil_Type32',
#        u'Soil_Type33', u'Soil_Type34', u'Soil_Type35', u'Soil_Type36',
#        u'Soil_Type37', u'Soil_Type38', u'Soil_Type39', u'Soil_Type40',
#        u'Cover_Type'],
#       dtype='object')

# %%
CATEGORICAL_VARIABLES = [u'Elevation', u'Aspect', u'Slope', u'Horizontal_Distance_To_Hydrology',
       u'Vertical_Distance_To_Hydrology', u'Horizontal_Distance_To_Roadways',
       u'Hillshade_9am', u'Hillshade_Noon', u'Hillshade_3pm',
       u'Horizontal_Distance_To_Fire_Points']
CONTINUOUS_VARIABLES = [u'Wilderness_Area1',
       u'Wilderness_Area2', u'Wilderness_Area3', u'Wilderness_Area4',
       u'Soil_Type1', u'Soil_Type2', u'Soil_Type3', u'Soil_Type4',
       u'Soil_Type5', u'Soil_Type6', u'Soil_Type7', u'Soil_Type8',
       u'Soil_Type9', u'Soil_Type10', u'Soil_Type11', u'Soil_Type12',
       u'Soil_Type13', u'Soil_Type14', u'Soil_Type15', u'Soil_Type16',
       u'Soil_Type17', u'Soil_Type18', u'Soil_Type19', u'Soil_Type20',
       u'Soil_Type21', u'Soil_Type22', u'Soil_Type23', u'Soil_Type24',
       u'Soil_Type25', u'Soil_Type26', u'Soil_Type27', u'Soil_Type28',
       u'Soil_Type29', u'Soil_Type30', u'Soil_Type31', u'Soil_Type32',
       u'Soil_Type33', u'Soil_Type34', u'Soil_Type35', u'Soil_Type36',
       u'Soil_Type37', u'Soil_Type38', u'Soil_Type39', u'Soil_Type40',]

# %% [markdown]
# # Neural Networks

# %%
X_standardized = deepcopy(train_df)
X_standardized[CATEGORICAL_VARIABLES] = StandardScaler().fit_transform(X_standardized[CATEGORICAL_VARIABLES])

y = X_standardized.Cover_Type
X = X_standardized.drop("Cover_Type", 1)

solvers = ['lbfgs', 'sgd', 'adam']
alphas = [0.0001, 0.001, 0.01, 0.1]
learning_rates = ['constant', 'invscaling', 'adaptive']
hidden_layer_sizes = [(len(X.columns),)]
param_grid = {'solver': solvers, 'alpha': alphas, 'learning_rate': learning_rates, 'hidden_layer_sizes': hidden_layer_sizes}

mpl_grid_search = RandomizedSearchCV(MLPClassifier(), param_grid, cv=5, verbose=3, n_jobs=2,  n_iter=10)
mpl_grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,)
# [CV] alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,), score=0.677579, total=  24.3s
# [CV] alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,), score=0.687831, total=  24.5s
# [CV] alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,), score=0.740741, total=  23.5s
# [CV] alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,), score=0.720569, total=  24.0s
# [CV] alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.692130, total=  11.9s
# [CV] alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.693122, total=  11.6s
# [CV] alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=invscaling, solver=adam, hidden_layer_sizes=(54,), score=0.801257, total=  27.1s
# [CV] alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.726521, total=  11.4s
# [CV] alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.746362, total=  12.3s
# [CV] alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.802249, total=  12.7s
# [CV] alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.696429, total=  13.0s
# [CV] alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.686839, total=  13.7s
# [CV] alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.725860, total=  12.8s
# [CV] alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.735450, total=  11.6s
# [CV] alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.815476, total=  12.0s
# [CV] alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,), score=0.688823, total=  11.7s
# [CV] alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,), score=0.698743, total=  11.2s
# [CV] alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,), score=0.718254, total=  11.5s
# [CV] alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,), score=0.744048, total=  11.9s
# [CV] alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.1, learning_rate=adaptive, solver=lbfgs, hidden_layer_sizes=(54,), score=0.810847, total=  11.7s
# [CV] alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.696429, total=  13.0s
# [CV] alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.709325, total=  13.1s
# [CV] alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.724868, total=  12.5s
# [CV] alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.743717, total=  12.2s
# [CV] alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=lbfgs, hidden_layer_sizes=(54,), score=0.796296, total=  12.3s
# [CV] alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,), score=0.614087, total=  23.3s
# [CV] alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,), score=0.631944, total=  24.6s
# [CV] alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,), score=0.683862, total=  24.4s
# [CV] alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,)
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:  3.8min
# [CV]  alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,), score=0.690476, total=  22.7s
# [CV] alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=adaptive, solver=sgd, hidden_layer_sizes=(54,), score=0.729167, total=  20.9s
# [CV] alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,), score=0.613426, total=  22.8s
# [CV] alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,), score=0.617063, total=  23.3s
# [CV] alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,), score=0.691468, total=  22.4s
# [CV] alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,), score=0.690146, total=  23.0s
# [CV] alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=constant, solver=sgd, hidden_layer_sizes=(54,), score=0.729828, total=  23.2s
# [CV] alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.230820, total=  12.0s
# [CV] alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.273479, total=  18.3s
# [CV] alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.248347, total=  22.3s
# [CV] alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.291336, total=  20.7s
# [CV] alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.01, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.227183, total=  18.7s
# [CV] alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.302910, total=  17.4s
# [CV] alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.176587, total=  16.9s
# [CV] alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.251653, total=  19.3s
# [CV] alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.259590, total=  16.3s
# [CV] alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,), score=0.679233, total=  12.3s
# [CV] alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.001, learning_rate=invscaling, solver=sgd, hidden_layer_sizes=(54,), score=0.251323, total=  22.9s
# [CV] alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,), score=0.691468, total=  12.4s
# [CV] alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,), score=0.729828, total=  12.4s
# [CV] alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,)
# [CV]  alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,), score=0.738757, total=  12.9s
# [CV]  alpha=0.0001, learning_rate=constant, solver=lbfgs, hidden_layer_sizes=(54,), score=0.815807, total=  10.3s
# [Parallel(n_jobs=2)]: Done  50 out of  50 | elapsed:  7.1min finished
# RandomizedSearchCV(cv=5, error_score='raise',
#           estimator=MLPClassifier(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#        beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=None,
#        shuffle=True, solver='adam', tol=0.0001, validation_fraction=0.1,
#        verbose=False, warm_start=False),
#           fit_params={}, iid=True, n_iter=10, n_jobs=2,
#           param_distributions={'alpha': [0.0001, 0.001, 0.01, 0.1], 'learning_rate': ['constant', 'invscaling', 'adaptive'], 'hidden_layer_sizes': [(54,)], 'solver': ['lbfgs', 'sgd', 'adam']},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score=True, scoring=None, verbose=3)

# %%
"""
Best params:
{'alpha': 0.001,
 'hidden_layer_sizes': (54,),
 'learning_rate': 'invscaling',
 'solver': 'lbfgs'}
Best score:
0.73412698412698407
"""

# %% [markdown]
# # Random Forest

# %%
y = train_df.Cover_Type
X = train_df.drop("Cover_Type", 1)

n_estimators = [10,20,50,100,500]
criterions = ['gini', 'entropy']
max_features = ['sqrt', 'log2']
min_samples_leaf = [1, 20, 50]

param_grid = {'criterion': criterions, 'n_estimators': n_estimators, 'max_features': max_features,
              'min_samples_leaf': min_samples_leaf}

rf_grid_search = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, verbose=3, n_jobs=2)
rf_grid_search.fit(X, y)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.698743, total=   0.2s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.707672, total=   0.2s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.748677, total=   0.2s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.756614, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.830688, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.723214, total=   0.4s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.732143, total=   0.4s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.758929, total=   0.4s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.774471, total=   0.4s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.837963, total=   0.4s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.739087, total=   0.9s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.735450, total=   0.9s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.767526, total=   0.9s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.790675, total=   0.9s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.847553, total=   0.9s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.747024, total=   1.8s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.743386, total=   1.8s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.767196, total=   1.8s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.801918, total=   1.8s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.848545, total=   1.7s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.749669, total=   8.9s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.739087, total=   9.0s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.772817, total=   9.2s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.806878, total=   9.0s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20, score=0.633598, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20, score=0.665013, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20, score=0.682209, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20, score=0.724206, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=20, score=0.769511, total=   0.1s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20
# [Parallel(n_jobs=2)]: Done  28 tasks      | elapsed:   30.9s
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20, score=0.639881, total=   0.3s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20, score=0.672288, total=   0.3s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20, score=0.702381, total=   0.3s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20, score=0.729167, total=   0.3s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=20, score=0.771495, total=   0.3s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20, score=0.648479, total=   0.6s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20, score=0.674603, total=   0.6s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20, score=0.700397, total=   0.6s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20, score=0.742394, total=   0.6s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=20, score=0.776786, total=   0.6s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20, score=0.631614, total=   1.2s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20, score=0.680886, total=   1.2s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.850198, total=   9.0s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20, score=0.694775, total=   1.3s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20, score=0.750992, total=   1.3s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=20, score=0.783730, total=   1.2s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20, score=0.648479, total=   5.9s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20, score=0.678241, total=   5.8s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20, score=0.700397, total=   5.9s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20, score=0.750000, total=   5.8s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50, score=0.579696, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50, score=0.632275, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50, score=0.666336, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50, score=0.693122, total=   0.1s
# [CV] max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=10, criterion=gini, min_samples_leaf=50, score=0.732804, total=   0.1s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50, score=0.621032, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50, score=0.656085, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50, score=0.687831, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50, score=0.695106, total=   0.2s
# [CV] max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=20, criterion=gini, min_samples_leaf=50, score=0.740741, total=   0.2s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50, score=0.620370, total=   0.5s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50, score=0.650794, total=   0.5s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50, score=0.673942, total=   0.5s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50, score=0.706349, total=   0.5s
# [CV] max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=50, criterion=gini, min_samples_leaf=50, score=0.745370, total=   0.5s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50, score=0.614418, total=   1.0s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=20, score=0.774802, total=   6.0s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50, score=0.655093, total=   1.0s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50, score=0.673611, total=   1.0s
# [CV] max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50, score=0.726852, total=   1.0s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=100, criterion=gini, min_samples_leaf=50, score=0.745370, total=   1.0s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50, score=0.618717, total=   5.2s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50, score=0.660384, total=   5.1s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50, score=0.718915, total=   5.1s
# [CV] max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50, score=0.679894, total=   5.2s
# [CV] max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.707672, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.708995, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.719907, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.759590, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=10, criterion=gini, min_samples_leaf=1, score=0.818122, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.722222, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.717593, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.751984, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.774140, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=gini, min_samples_leaf=1, score=0.831019, total=   0.3s
# [CV] max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.733466, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.733796, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.756614, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=gini, min_samples_leaf=50, score=0.748677, total=   5.2s
# [CV] max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.793320, total=   0.8s
# [CV] max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=gini, min_samples_leaf=1, score=0.844577, total=   0.8s
# [CV] max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.736772, total=   1.6s
# [CV] max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.735450, total=   1.6s
# [CV] max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.760251, total=   1.5s
# [CV] max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.803571, total=   1.6s
# [CV] max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=gini, min_samples_leaf=1, score=0.840278, total=   1.6s
# [CV] max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.744048, total=   7.9s
# [CV] max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.738757, total=   8.0s
# [CV] max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0.766865, total=   8.3s
# [CV] max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=gini, min_samples_leaf=1, score=0

# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=1, score=0.828373, total=   0.5s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1, score=0.742063, total=   1.2s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=sqrt, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.738757, total=   7.0s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1, score=0.732804, total=   1.2s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1, score=0.765542, total=   1.3s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1, score=0.792989, total=   1.3s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=1, score=0.841931, total=   1.3s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1, score=0.734458, total=   2.5s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1, score=0.735450, total=   2.5s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1, score=0.762897, total=   2.5s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1, score=0.803902, total=   2.6s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=1, score=0.847884, total=   2.6s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1, score=0.738757, total=  13.0s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1, score=0.735450, total=  12.7s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1, score=0.762897, total=  13.0s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1, score=0.805556, total=  12.7s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20, score=0.602183, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20, score=0.651786, total=   0.1s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20, score=0.668320, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20, score=0.698413, total=   0.2s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=20, score=0.736442, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20, score=0.637566, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20, score=0.657738, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20, score=0.671296, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20, score=0.716601, total=   0.3s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=20, score=0.751984, total=   0.4s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20, score=0.623016, total=   0.7s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20, score=0.666005, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20, score=0.689815, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20, score=0.732804, total=   0.8s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=20, score=0.756283, total=   0.8s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20, score=0.628638, total=   1.4s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20, score=0.674272, total=   1.4s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20, score=0.678571, total=   1.5s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20, score=0.739087, total=   1.4s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=1, score=0.846892, total=  14.1s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=20, score=0.759921, total=   1.4s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20, score=0.633267, total=   6.8s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20, score=0.666667, total=   6.9s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20, score=0.690146, total=   6.9s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20, score=0.742725, total=   6.8s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50, score=0.591270, total=   0.1s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50, score=0.610780, total=   0.1s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50, score=0.652778, total=   0.1s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50, score=0.673611, total=   0.1s
# [CV] max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=10, criterion=entropy, min_samples_leaf=50, score=0.712963, total=   0.1s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50, score=0.564484, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50, score=0.644511, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50, score=0.657738, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50, score=0.697090, total=   0.2s
# [CV] max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=20, criterion=entropy, min_samples_leaf=50, score=0.724537, total=   0.2s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50
# [Parallel(n_jobs=2)]: Done 284 tasks      | elapsed:  5.6min
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50, score=0.598545, total=   0.5s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50, score=0.644180, total=   0.5s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50, score=0.654762, total=   0.5s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50, score=0.706019, total=   0.5s
# [CV] max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=50, criterion=entropy, min_samples_leaf=50, score=0.725198, total=   0.5s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=20, score=0.764881, total=   6.8s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50, score=0.593915, total=   1.1s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50, score=0.651124, total=   1.1s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50, score=0.668981, total=   1.0s
# [CV] max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50, score=0.709325, total=   1.1s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=100, criterion=entropy, min_samples_leaf=50, score=0.730489, total=   1.1s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.607804, total=   5.4s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.641534, total=   5.4s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.667328, total=   5.4s
# [CV] max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.710317, total=   5.4s
# [CV]  max_features=log2, n_estimators=500, criterion=entropy, min_samples_leaf=50, score=0.730159, total=   5.5s
# [Parallel(n_jobs=2)]: Done 300 out of 300 | elapsed:  6.0min finished
# GridSearchCV(cv=5, error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=2,
#        param_grid={'n_estimators': [10, 20, 50, 100, 500], 'max_features': ['sqrt', 'log2'], 'criterion': ['gini', 'entropy'], 'min_samples_leaf': [1, 20, 50]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=3)

# %%
print rf_grid_search.best_params_
print rf_grid_search.best_score_
# Out:
# {'max_features': 'sqrt', 'n_estimators': 500, 'criterion': 'gini', 'min_samples_leaf': 1}
# 0.78373015873

# %%
"""
Best params:
{'max_features': 'sqrt', 'n_estimators': 500, 'criterion': 'gini', 'min_samples_leaf': 1}
Best score:
0.78373015873
"""
# Out:
# "\nBest params:\n{'max_features': 'sqrt', 'n_estimators': 500, 'criterion': 'gini', 'min_samples_leaf': 1}\nBest score:\n0.78373015873\n"

# %%
y = train_df.Cover_Type
X = train_df.drop("Cover_Type", 1)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

rf = RandomForestClassifier(criterion='gini', n_estimators=500, max_features='sqrt', min_samples_leaf=1)
rf.fit(X_train, y_train)
preds = rf.predict(X_test)

print sklearn.metrics.accuracy_score(y_test, preds)
# Out:
# 0.863756613757
